# %% [markdown]
# ### YOLOv11 - PPE

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\davi emmerick\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
yaml_path = "dataset/data.yaml"

model = YOLO("yolo11n.pt")

print(f"Iniciando treinamento > {yaml_path}")

results = model.train (
    data = yaml_path,

    device='cpu',      
    workers=0,         
    batch=4,           
    
    epochs=10,         
    imgsz=640,         
    patience=5,        
    
    project='runs/detect',       
    name='treino_epi_v1',        
    exist_ok=True,               
    verbose=True


)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 6.0MB/s 0.9s.8s<0.1s.1s
# Iniciando treinamento > dataset/data.yaml
# Ultralytics 8.3.243  Python-3.12.0 torch-2.9.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=treino_epi_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\davi emmerick\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 7.0MB/s 0.1s 0.1s<0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.50.6 ms, read: 4.81.8 MB/s, size: 56.9 KB)
# train: Scanning C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\dataset\train\labels... 592 images, 48 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 592/592 231.6it/s 2.6s0.2s
# train: New cache created: C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\dataset\train\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 373, len(boxes) = 1453. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.50.1 ms, read: 2.61.5 MB/s, size: 39.1 KB)
# val: Scanning C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\dataset\valid\labels... 39 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 39/39 225.6it/s 0.2s.4s
# val: New cache created: C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\dataset\valid\labels.cache
# Plotting labels to C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.189      2.793       1.33          9        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 4:041.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2s/it 5.9s1.6ss
#                    all         39         72      0.314      0.306      0.217      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      1.091      2.094      1.316          6        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 3:551.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.4s1.4ss
#                    all         39         72      0.588      0.264      0.309      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G      1.059      1.898      1.283         10        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 4:021.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.6s1.5ss
#                    all         39         72       0.78      0.264      0.334      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G      1.033      1.554      1.274          5        640: 100% ━━━━━━━━━━━━ 148/148 1.5s/it 3:461.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.2s1.4ss
#                    all         39         72      0.561      0.361      0.418      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G     0.9382      1.359      1.239          4        640: 100% ━━━━━━━━━━━━ 148/148 1.5s/it 3:461.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.7s1.5ss
#                    all         39         72      0.691      0.236      0.333      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      0.918      1.168      1.181         25        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 3:591.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.5s1.4ss
#                    all         39         72      0.645      0.555      0.554      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G     0.8651      1.054      1.158         19        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 3:581.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.2s1.4ss
#                    all         39         72      0.588      0.556      0.532      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G     0.7861     0.9735      1.119          4        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 3:521.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.3s1.4ss
#                    all         39         72      0.648      0.597      0.594      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G     0.7441     0.8765      1.124         13        640: 100% ━━━━━━━━━━━━ 148/148 1.6s/it 3:571.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.1s1.4ss
#                    all         39         72      0.667      0.583      0.655      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G     0.7153     0.8186      1.075          8        640: 100% ━━━━━━━━━━━━ 148/148 1.4s/it 3:261.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.6s1.2ss
#                    all         39         72      0.684      0.611      0.691      0.464
#
# 10 epochs completed in 0.661 hours.
# Optimizer stripped from C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1\weights\last.pt, 5.5MB
# Optimizer stripped from C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1\weights\best.pt, 5.5MB
#
# Validating C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1\weights\best.pt...
# Ultralytics 8.3.243  Python-3.12.0 torch-2.9.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.1s1.1ss
#                    all         39         72      0.684      0.611       0.69      0.464
# Speed: 3.0ms preprocess, 87.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\davi emmerick\Projetos\ppe-detection-yolo\ppe-detection-yolo\runs\detect\treino_epi_v1
